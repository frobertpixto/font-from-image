# %% [markdown]
# # Train a model to learn Font names from text in an image
# ### Using Supervised Learning with Tensorflow
#
# Data is received in a pickle that contains:
# - List of font names
# - Images: 50px x 50px white on black images (in gray colorspace -> 1 color channel)
# - Labels: 0..(nb_fonts-1)
# ---
# Francois Robert

# %%
### Load packages
from IPython.display import display, Image
import imageio
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import os
from six.moves import cPickle as pickle

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

import tensorflow as tf

from tensorflow.keras.utils import to_categorical # convert to one-hot-encoding
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, BatchNormalization, Activation, Input, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from tensorflow.keras.preprocessing import image

# %%
from platform import python_version

print(python_version())
# Out:
# 3.8.5

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %%
seed = 12
np.random.seed(seed)

# %%
### Define environment variables
BASE_DIR = "/private/var/folders/dg/d26lcf2j32x077lbqlcjld5h0000gn/T/com.pixtolab.GenerateFontImages" 

DATAFILE = os.path.join(BASE_DIR, 'prep1', 'prep1.pickle')

# %% [markdown]
# ## Load pickled data dictionary containing trained, validation datasets

# %%
with open(DATAFILE, 'rb') as f:
    data_dict = pickle.load(f)

# %%
# Show the actual font names in the dataaz
output_labels = data_dict['font_names']

print("Fonts")
for label, font_name in enumerate(output_labels):
    print(f"{label}: {font_name}")
# Out:
# Fonts
# 0: Aladin-Regular
# 1: AlexBrush-Regular
# 2: Allura-Regular
# 3: AmaticSC-Regular
# 4: AmericanTypewriter-Condensed
# 5: Bonbon-Regular
# 6: BowlbyOneSC-Regular
# 7: BradleyHandITCTT-Bold
# 8: BrushScriptMT
# 9: CarterOne
# 10: Chalkduster
# 11: Cookie-Regular
# 12: Copperplate
# 13: CourierNewPSMT
# 14: Damion
# 15: DancingScript-Bold
# 16: Didot
# 17: FredokaOne-Regular
# 18: Futura-CondensedMedium
# 19: GochiHand-Regular
# 20: GrandHotel-Regular
# 21: GreatVibes-Regular
# 22: Helvetica-Bold
# 23: HelveticaNeue
# 24: Impact
# 25: Luminari-Regular
# 26: MarkerFelt-Thin
# 27: Noteworthy-Light
# 28: Optima-Regular
# 29: Pacifico-Regular
# 30: RockSalt
# 31: Rockwell-Regular
# 32: Shojumaru-Regular
# 33: TimesNewRomanPSMT
# 34: Yesteryear-Regular

# %%
image_size  = 50     # Pixel width and height
pixel_depth = 255.0  # Number of levels per pixel

# %%
nb_fonts = len(output_labels)

X = data_dict['images']
y = data_dict['labels']

images_per_font = X.shape[0] / nb_fonts

# Construct training set and validation set
train_X, val_X, train_y, val_y = train_test_split(X, y, test_size=0.2, random_state=seed)

# %%
# Training set
train_X.shape, train_y.shape
# Out:
# ((23240, 50, 50), (23240,))

# %%
# Validation set
val_X.shape, val_y.shape
# Out:
# ((5810, 50, 50), (5810,))

# %%
images_per_font
# Out:
# 830.0

# %%
# Reshape images to add the channel (height = 50px, width = 50px , channel = 1)
X_train = train_X.reshape(-1, image_size, image_size, 1)
X_val   = val_X.reshape(-1, image_size, image_size, 1)

# %% [markdown]
# ## Let's see how the data looks like

# %%
def plot_sample(image, axs):
   
    axs.imshow(image.reshape(image_size, image_size), cmap="gray")

# %%
def display_images(X, Y):
    """ This function shows 25 images with their real labels"""

    fig = plt.figure(figsize=(13, 9))
    fig.subplots_adjust(hspace=1.1,wspace=0.1,
                        left=0,right=1,bottom=0, top=1)
    nb_pictures = 25

    for i in range(nb_pictures):
        ax = fig.add_subplot(nb_pictures//5 , 5, i+1, xticks=[], yticks=[]) 
        plot_sample(X[i].reshape((image_size, image_size)), ax)
        ax.set_title("{}".format(output_labels[Y[i]]))
    plt.show()

# %% [markdown]
# ### Some Training data. Images with labels

# %%
display_images(X_train[:25],train_y[:25])

# %% [markdown]
# ### Some Validation data

# %%
display_images(X_val[:25],val_y[:25])

# %%
# Some examples from train set
# g = plt.imshow(X_train[15][:,:,0])

# %%
# Let's see the label's shape before one hot encoding
train_y.shape,val_y.shape
# Out:
# ((23240,), (5810,))

# %%
# Encode labels to one hot vectors 
Y_train = to_categorical(train_y, num_classes = nb_fonts)
Y_val   = to_categorical(val_y,   num_classes = nb_fonts)

# %%
X_train.shape,X_val.shape
# Out:
# ((23240, 50, 50, 1), (5810, 50, 50, 1))

# %%
Y_train.shape,Y_val.shape
# Out:
# ((23240, 35), (5810, 35))

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Define the model

# %%
def get_model_cnn1():
    # Set the CNN model using Keras functional API
    input_img = Input(shape=(image_size,image_size,1))

    x = Conv2D(32, (5, 5), padding='same')(input_img)  # Conv2D 1
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (5, 5), padding='same')(x)          # Conv2D 2
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(64, (5, 5))(x)                          # Conv2D 3
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3))(x)                          # Conv2D 4
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.2)(x)

    x = Conv2D(128, (3, 3))(x)                         # Conv2D 5
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3))(x)                         # Conv2D 6
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(0.3)(x)

    x = Flatten()(x)
    x = Dense(128)(x)  
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.4)(x)
    output = Dense(nb_fonts, activation = "softmax")(x)

    model = Model(inputs=input_img, outputs=output)
    
    return model

# %%
# select a model
model = get_model_cnn1()

model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 50, 50, 32)        832
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        25632
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# activation_1 (Activation)    (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 46, 46, 64)        51264
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# activation_2 (Activation)    (None, 46, 46, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 44, 44, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 44, 44, 64)        256
# _________________________________________________________________
# activation_3 (Activation)    (None, 44, 44, 64)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 22, 22, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 20, 20, 128)       512
# _________________________________________________________________
# activation_4 (Activation)    (None, 20, 20, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 18, 18, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# activation_5 (Activation)    (None, 18, 18, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 9, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 9, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 10368)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1327232
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 128)               512
# _________________________________________________________________
# activation_6 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 35)                4515
# =================================================================
# Total params: 1,670,147
# Trainable params: 1,668,995
# Non-trainable params: 1,152
# _________________________________________________________________

# %% [markdown]
# ## Compile the model

# %%
# We do data augmentation to prevent overfitting and adapt better.
# If used against non generated data, I should do much more augmentation.
datagen = ImageDataGenerator(
        featurewise_center=False,             # set input mean to 0 over the dataset
        samplewise_center=False,              # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,   # divide each input by its std
        zca_whitening=False,                  # apply ZCA whitening
        rotation_range=0,                     # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = [0.9, 1.11],             # Randomly zoom image 
        width_shift_range=0.05,               # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.05,              # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,                # randomly flip images
        vertical_flip=False)                  # randomly flip images

# %%
# Keras callback to the result of the best epoch in the model
# Intended to work with ModelCheckpoint callback.
class ShowBestEpochResult(tf.keras.callbacks.Callback):
    def __init__(self, on_param='val_loss', show_params=['val_loss', 'loss'], mode='min'):
        self.on_param    = on_param
        self.show_params = show_params
        self.mode        = mode

    def on_train_begin(self, logs=None):
        # The number of epoch at which the best value is found.
        self.best_epoch = 0

        # The best value found for the on_param.
        self.best = np.Inf
        if self.mode == 'max':
            self.best = np.NINF
            
        # The values on best epoch for each param in show_param.
        self.best_values = {}

    def on_epoch_end(self, epoch, logs=None):
        current = logs.get(self.on_param)
        save_as_best = (self.mode=='min' and current < self.best) or \
                       (self.mode=='max' and current > self.best)

        if save_as_best: 
            self.best = current
            for param in self.show_params:
                self.best_values[param] = logs.get(param)
            self.best_epoch = epoch

    def on_train_end(self, logs=None):
        print(f"BestEpochResult. Epoch: {self.best_epoch+1},", end=" ")

        for param in self.best_values:
            print(f"{param}: {self.best_values[param]:.5f},", end=" ")
        print(" ")

# %%
# Define the optimizer. Adam is generally my best bet.
optimizer = Adam(lr=0.0001, decay=0.0)

# %%
# Compile the model
model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
# Lower the learning rate if accuracy stops improving.
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=8, 
                                            verbose=1, 
                                            factor=0.8, 
                                            min_delta=1e-7,
                                            min_lr=1e-7)

#TensorBoard
# tensorBoard = TensorBoard(log_dir='./Graph', 
#                                          histogram_freq=0, 
#                                          write_graph=True, 
#                                          write_images=True)

# %% [markdown]
# ## Train the model

# %%
# Fit the model with data Augmentation
# I like to start a few epoch with a small batch size because:
# - This basically makes the learning rate larger. https://openreview.net/pdf?id=B1Yy1BxCZ#:~:text=Increasing%20the%20batch%20size%20during%20training%20achieves%20similar%20results%20to,twice%20to%20illustrate%20the%20variance.
# - This covers to 0 to 80% of the accuracy curve, cleaning the graphs
epochs = 2 # Turn epochs to ...
batch_size = 32  
history = model.fit(datagen.flow(X_train,Y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (X_val, Y_val),
                              verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Epoch 1/2
# 726/726 [==============================] - 10s 14ms/step - loss: 2.4527 - accuracy: 0.3205 - val_loss: 1.3551 - val_accuracy: 0.7083
# Epoch 2/2
# 726/726 [==============================] - 10s 13ms/step - loss: 1.3425 - accuracy: 0.6345 - val_loss: 0.7464 - val_accuracy: 0.8685

# %%
# From now on, we will save the model with the best accuracy
h5_path    = "FontFromImage.model.h5"
checkpoint = ModelCheckpoint(h5_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
       
best_epoch_results = ShowBestEpochResult(on_param='val_accuracy', 
                                         show_params=['val_accuracy', 'accuracy', 'val_loss', 'loss'], 
                                         mode='max')

callbacks_list = [learning_rate_reduction, checkpoint, best_epoch_results]

epochs = 120
batch_size = 128  
history = model.fit(datagen.flow(X_train,Y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (X_val, Y_val),
                              verbose = 1, steps_per_epoch=X_train.shape[0] // batch_size,
                              callbacks=callbacks_list)
# Out:
# Epoch 1/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.9230 - accuracy: 0.7696
# Epoch 00001: val_accuracy improved from -inf to 0.92806, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 9s 48ms/step - loss: 0.9228 - accuracy: 0.7696 - val_loss: 0.5460 - val_accuracy: 0.9281
# Epoch 2/120
# 181/181 [==============================] - ETA: 0s - loss: 0.8112 - accuracy: 0.7995
# Epoch 00002: val_accuracy did not improve from 0.92806
# 181/181 [==============================] - 8s 45ms/step - loss: 0.8112 - accuracy: 0.7995 - val_loss: 0.5630 - val_accuracy: 0.8804
# Epoch 3/120
# 181/181 [==============================] - ETA: 0s - loss: 0.7231 - accuracy: 0.8285
# Epoch 00003: val_accuracy did not improve from 0.92806
# 181/181 [==============================] - 8s 46ms/step - loss: 0.7231 - accuracy: 0.8285 - val_loss: 0.4424 - val_accuracy: 0.9231
# Epoch 4/120
# 181/181 [==============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.8473
# Epoch 00004: val_accuracy improved from 0.92806 to 0.95370, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.6481 - accuracy: 0.8473 - val_loss: 0.3171 - val_accuracy: 0.9537
# Epoch 5/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.5817 - accuracy: 0.8655
# Epoch 00005: val_accuracy did not improve from 0.95370
# 181/181 [==============================] - 8s 46ms/step - loss: 0.5815 - accuracy: 0.8655 - val_loss: 0.4191 - val_accuracy: 0.9120
# Epoch 6/120
# 181/181 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.8839
# Epoch 00006: val_accuracy did not improve from 0.95370
# 181/181 [==============================] - 8s 46ms/step - loss: 0.5156 - accuracy: 0.8839 - val_loss: 0.4187 - val_accuracy: 0.8924
# Epoch 7/120
# 181/181 [==============================] - ETA: 0s - loss: 0.4599 - accuracy: 0.9005
# Epoch 00007: val_accuracy improved from 0.95370 to 0.96558, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.4599 - accuracy: 0.9005 - val_loss: 0.2234 - val_accuracy: 0.9656
# Epoch 8/120
# 181/181 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.9120
# Epoch 00008: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.4097 - accuracy: 0.9120 - val_loss: 0.2073 - val_accuracy: 0.9633
# Epoch 9/120
# 181/181 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.9173
# Epoch 00009: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.3714 - accuracy: 0.9173 - val_loss: 0.2344 - val_accuracy: 0.9460
# Epoch 10/120
# 181/181 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.9296
# Epoch 00010: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.3333 - accuracy: 0.9296 - val_loss: 0.1888 - val_accuracy: 0.9647
# Epoch 11/120
# 181/181 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.9389
# Epoch 00011: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.2978 - accuracy: 0.9389 - val_loss: 0.4642 - val_accuracy: 0.8627
# Epoch 12/120
# 181/181 [==============================] - ETA: 0s - loss: 0.2719 - accuracy: 0.9428
# Epoch 00012: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.2719 - accuracy: 0.9428 - val_loss: 0.2762 - val_accuracy: 0.9219
# Epoch 13/120
# 181/181 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9485
# Epoch 00013: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.2513 - accuracy: 0.9485 - val_loss: 0.1639 - val_accuracy: 0.9644
# Epoch 14/120
# 181/181 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.9522
# Epoch 00014: val_accuracy did not improve from 0.96558
# 181/181 [==============================] - 8s 46ms/step - loss: 0.2309 - accuracy: 0.9522 - val_loss: 0.1763 - val_accuracy: 0.9573
# Epoch 15/120
# 181/181 [==============================] - ETA: 0s - loss: 0.2083 - accuracy: 0.9559
# Epoch 00015: val_accuracy improved from 0.96558 to 0.97418, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.2083 - accuracy: 0.9559 - val_loss: 0.1117 - val_accuracy: 0.9742
# Epoch 16/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9585
# Epoch 00016: val_accuracy improved from 0.97418 to 0.97573, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.1970 - accuracy: 0.9585 - val_loss: 0.0989 - val_accuracy: 0.9757
# Epoch 17/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9609
# Epoch 00017: val_accuracy did not improve from 0.97573
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1793 - accuracy: 0.9609 - val_loss: 0.1455 - val_accuracy: 0.9647
# Epoch 18/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9651
# Epoch 00018: val_accuracy did not improve from 0.97573
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1679 - accuracy: 0.9651 - val_loss: 0.2182 - val_accuracy: 0.9337
# Epoch 19/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.9684
# Epoch 00019: val_accuracy did not improve from 0.97573
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1549 - accuracy: 0.9684 - val_loss: 0.1833 - val_accuracy: 0.9432
# Epoch 20/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1459 - accuracy: 0.9695
# Epoch 00020: val_accuracy did not improve from 0.97573
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1459 - accuracy: 0.9695 - val_loss: 0.1620 - val_accuracy: 0.9571
# Epoch 21/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9706
# Epoch 00021: val_accuracy improved from 0.97573 to 0.98141, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.1379 - accuracy: 0.9706 - val_loss: 0.0762 - val_accuracy: 0.9814
# Epoch 22/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1231 - accuracy: 0.9737
# Epoch 00022: val_accuracy did not improve from 0.98141
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1231 - accuracy: 0.9737 - val_loss: 0.1890 - val_accuracy: 0.9404
# Epoch 23/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9734
# Epoch 00023: val_accuracy did not improve from 0.98141
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1198 - accuracy: 0.9734 - val_loss: 0.1431 - val_accuracy: 0.9594
# Epoch 24/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1111 - accuracy: 0.9764
# Epoch 00024: val_accuracy did not improve from 0.98141
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1111 - accuracy: 0.9764 - val_loss: 0.0912 - val_accuracy: 0.9744
# Epoch 25/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9759
# Epoch 00025: val_accuracy did not improve from 0.98141
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1083 - accuracy: 0.9759 - val_loss: 0.1295 - val_accuracy: 0.9620
# Epoch 26/120
# 181/181 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9781
# Epoch 00026: val_accuracy did not improve from 0.98141
# 181/181 [==============================] - 8s 46ms/step - loss: 0.1013 - accuracy: 0.9781 - val_loss: 0.1122 - val_accuracy: 0.9652
# Epoch 27/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9778
# Epoch 00027: val_accuracy did not improve from 0.98141
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0993 - accuracy: 0.9778 - val_loss: 0.1360 - val_accuracy: 0.9571
# Epoch 28/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0918 - accuracy: 0.9801
# Epoch 00028: val_accuracy improved from 0.98141 to 0.98709, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0918 - accuracy: 0.9801 - val_loss: 0.0490 - val_accuracy: 0.9871
# Epoch 29/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 0.9797
# Epoch 00029: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0882 - accuracy: 0.9797 - val_loss: 0.0619 - val_accuracy: 0.9826
# Epoch 30/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9808
# Epoch 00030: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0846 - accuracy: 0.9808 - val_loss: 0.1786 - val_accuracy: 0.9399
# Epoch 31/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0803 - accuracy: 0.9822
# Epoch 00031: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0803 - accuracy: 0.9822 - val_loss: 0.0680 - val_accuracy: 0.9840
# Epoch 32/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9846
# Epoch 00032: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0718 - accuracy: 0.9846 - val_loss: 0.1825 - val_accuracy: 0.9454
# Epoch 33/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9831
# Epoch 00033: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0728 - accuracy: 0.9831 - val_loss: 0.0604 - val_accuracy: 0.9847
# Epoch 34/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9837
# Epoch 00034: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0704 - accuracy: 0.9837 - val_loss: 0.0747 - val_accuracy: 0.9793
# Epoch 35/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9855
# Epoch 00035: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0657 - accuracy: 0.9855 - val_loss: 0.1819 - val_accuracy: 0.9434
# Epoch 36/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0661 - accuracy: 0.9851
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 7.999999797903001e-05.
#
# Epoch 00036: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0661 - accuracy: 0.9851 - val_loss: 0.0772 - val_accuracy: 0.9785
# Epoch 37/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9868
# Epoch 00037: val_accuracy did not improve from 0.98709
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0593 - accuracy: 0.9868 - val_loss: 0.1446 - val_accuracy: 0.9482
# Epoch 38/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9868
# Epoch 00038: val_accuracy improved from 0.98709 to 0.98812, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0563 - accuracy: 0.9868 - val_loss: 0.0470 - val_accuracy: 0.9881
# Epoch 39/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9868
# Epoch 00039: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0549 - accuracy: 0.9868 - val_loss: 0.0726 - val_accuracy: 0.9811
# Epoch 40/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0516 - accuracy: 0.9874
# Epoch 00040: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0516 - accuracy: 0.9874 - val_loss: 0.0767 - val_accuracy: 0.9792
# Epoch 41/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9882
# Epoch 00041: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0507 - accuracy: 0.9882 - val_loss: 0.0738 - val_accuracy: 0.9776
# Epoch 42/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0498 - accuracy: 0.9876
# Epoch 00042: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0498 - accuracy: 0.9876 - val_loss: 0.0595 - val_accuracy: 0.9845
# Epoch 43/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0486 - accuracy: 0.9877
# Epoch 00043: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0487 - accuracy: 0.9877 - val_loss: 0.0476 - val_accuracy: 0.9864
# Epoch 44/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9888
# Epoch 00044: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0459 - accuracy: 0.9888 - val_loss: 0.0757 - val_accuracy: 0.9788
# Epoch 45/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9900
# Epoch 00045: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0440 - accuracy: 0.9900 - val_loss: 0.0613 - val_accuracy: 0.9838
# Epoch 46/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9901
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 6.399999838322402e-05.
#
# Epoch 00046: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0431 - accuracy: 0.9901 - val_loss: 0.0993 - val_accuracy: 0.9676
# Epoch 47/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9905
# Epoch 00047: val_accuracy did not improve from 0.98812
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0415 - accuracy: 0.9905 - val_loss: 0.0540 - val_accuracy: 0.9862
# Epoch 48/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 0.9911
# Epoch 00048: val_accuracy improved from 0.98812 to 0.99002, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0387 - accuracy: 0.9911 - val_loss: 0.0430 - val_accuracy: 0.9900
# Epoch 49/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9920
# Epoch 00049: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0380 - accuracy: 0.9920 - val_loss: 0.0501 - val_accuracy: 0.9885
# Epoch 50/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9913
# Epoch 00050: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0374 - accuracy: 0.9913 - val_loss: 0.0465 - val_accuracy: 0.9880
# Epoch 51/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9912
# Epoch 00051: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0364 - accuracy: 0.9912 - val_loss: 0.0511 - val_accuracy: 0.9874
# Epoch 52/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9916
# Epoch 00052: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0351 - accuracy: 0.9916 - val_loss: 0.0726 - val_accuracy: 0.9802
# Epoch 53/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0350 - accuracy: 0.9916
# Epoch 00053: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0350 - accuracy: 0.9916 - val_loss: 0.1517 - val_accuracy: 0.9534
# Epoch 54/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9920
# Epoch 00054: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0346 - accuracy: 0.9920 - val_loss: 0.0657 - val_accuracy: 0.9816
# Epoch 55/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9925
# Epoch 00055: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0321 - accuracy: 0.9925 - val_loss: 0.0476 - val_accuracy: 0.9881
# Epoch 56/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 0.9915
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 5.119999987073243e-05.
#
# Epoch 00056: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0333 - accuracy: 0.9915 - val_loss: 0.0718 - val_accuracy: 0.9812
# Epoch 57/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9925
# Epoch 00057: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0308 - accuracy: 0.9925 - val_loss: 0.0821 - val_accuracy: 0.9761
# Epoch 58/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0309 - accuracy: 0.9926
# Epoch 00058: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0308 - accuracy: 0.9927 - val_loss: 0.0519 - val_accuracy: 0.9880
# Epoch 59/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9923
# Epoch 00059: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0306 - accuracy: 0.9923 - val_loss: 0.0982 - val_accuracy: 0.9704
# Epoch 60/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9932
# Epoch 00060: val_accuracy did not improve from 0.99002
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0289 - accuracy: 0.9932 - val_loss: 0.0545 - val_accuracy: 0.9869
# Epoch 61/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9933
# Epoch 00061: val_accuracy improved from 0.99002 to 0.99019, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0276 - accuracy: 0.9933 - val_loss: 0.0421 - val_accuracy: 0.9902
# Epoch 62/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9941
# Epoch 00062: val_accuracy did not improve from 0.99019
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0260 - accuracy: 0.9941 - val_loss: 0.0649 - val_accuracy: 0.9830
# Epoch 63/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9932
# Epoch 00063: val_accuracy did not improve from 0.99019
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0304 - accuracy: 0.9932 - val_loss: 0.1333 - val_accuracy: 0.9559
# Epoch 64/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0283 - accuracy: 0.9934
# Epoch 00064: val_accuracy improved from 0.99019 to 0.99122, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0283 - accuracy: 0.9934 - val_loss: 0.0383 - val_accuracy: 0.9912
# Epoch 65/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.9941
# Epoch 00065: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0260 - accuracy: 0.9941 - val_loss: 0.0950 - val_accuracy: 0.9694
# Epoch 66/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9946
# Epoch 00066: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0247 - accuracy: 0.9946 - val_loss: 0.0585 - val_accuracy: 0.9835
# Epoch 67/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.9944
# Epoch 00067: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0246 - accuracy: 0.9945 - val_loss: 0.0383 - val_accuracy: 0.9910
# Epoch 68/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9938
# Epoch 00068: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0253 - accuracy: 0.9938 - val_loss: 0.0449 - val_accuracy: 0.9895
# Epoch 69/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9941
# Epoch 00069: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0246 - accuracy: 0.9941 - val_loss: 0.0395 - val_accuracy: 0.9905
# Epoch 70/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0277 - accuracy: 0.9932
# Epoch 00070: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0280 - accuracy: 0.9930 - val_loss: 0.0488 - val_accuracy: 0.9883
# Epoch 71/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9941
# Epoch 00071: val_accuracy did not improve from 0.99122
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0247 - accuracy: 0.9941 - val_loss: 0.0432 - val_accuracy: 0.9892
# Epoch 72/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9949
# Epoch 00072: val_accuracy improved from 0.99122 to 0.99139, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0227 - accuracy: 0.9949 - val_loss: 0.0403 - val_accuracy: 0.9914
# Epoch 73/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9946
# Epoch 00073: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0231 - accuracy: 0.9946 - val_loss: 0.0430 - val_accuracy: 0.9904
# Epoch 74/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.9949
# Epoch 00074: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0225 - accuracy: 0.9949 - val_loss: 0.0533 - val_accuracy: 0.9876
# Epoch 75/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9942
# Epoch 00075: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0239 - accuracy: 0.9942 - val_loss: 0.0718 - val_accuracy: 0.9818
# Epoch 76/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9946
# Epoch 00076: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0214 - accuracy: 0.9946 - val_loss: 0.0439 - val_accuracy: 0.9893
# Epoch 77/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9958
# Epoch 00077: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0197 - accuracy: 0.9958 - val_loss: 0.0527 - val_accuracy: 0.9878
# Epoch 78/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9946
# Epoch 00078: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0230 - accuracy: 0.9946 - val_loss: 0.0461 - val_accuracy: 0.9904
# Epoch 79/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0206 - accuracy: 0.9953
# Epoch 00079: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0206 - accuracy: 0.9953 - val_loss: 0.0477 - val_accuracy: 0.9885
# Epoch 80/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9952
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 4.0960000478662555e-05.
#
# Epoch 00080: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0205 - accuracy: 0.9952 - val_loss: 0.0827 - val_accuracy: 0.9749
# Epoch 81/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9961
# Epoch 00081: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0174 - accuracy: 0.9961 - val_loss: 0.0474 - val_accuracy: 0.9892
# Epoch 82/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9960
# Epoch 00082: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0179 - accuracy: 0.9960 - val_loss: 0.0439 - val_accuracy: 0.9902
# Epoch 83/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9962
# Epoch 00083: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0178 - accuracy: 0.9962 - val_loss: 0.0436 - val_accuracy: 0.9910
# Epoch 84/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9956
# Epoch 00084: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0195 - accuracy: 0.9956 - val_loss: 0.0467 - val_accuracy: 0.9885
# Epoch 85/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9961
# Epoch 00085: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0171 - accuracy: 0.9961 - val_loss: 0.0624 - val_accuracy: 0.9857
# Epoch 86/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9957
# Epoch 00086: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0192 - accuracy: 0.9957 - val_loss: 0.0462 - val_accuracy: 0.9886
# Epoch 87/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9955
# Epoch 00087: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0198 - accuracy: 0.9955 - val_loss: 0.0427 - val_accuracy: 0.9912
# Epoch 88/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9963
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 3.2767999800853435e-05.
#
# Epoch 00088: val_accuracy did not improve from 0.99139
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0177 - accuracy: 0.9963 - val_loss: 0.0470 - val_accuracy: 0.9895
# Epoch 89/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0171 - accuracy: 0.9960
# Epoch 00089: val_accuracy improved from 0.99139 to 0.99174, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0171 - accuracy: 0.9960 - val_loss: 0.0359 - val_accuracy: 0.9917
# Epoch 90/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9965
# Epoch 00090: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0147 - accuracy: 0.9965 - val_loss: 0.0402 - val_accuracy: 0.9910
# Epoch 91/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9963
# Epoch 00091: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0162 - accuracy: 0.9963 - val_loss: 0.0374 - val_accuracy: 0.9916
# Epoch 92/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9966
# Epoch 00092: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0151 - accuracy: 0.9966 - val_loss: 0.0545 - val_accuracy: 0.9864
# Epoch 93/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0158 - accuracy: 0.9963
# Epoch 00093: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0158 - accuracy: 0.9963 - val_loss: 0.0403 - val_accuracy: 0.9897
# Epoch 94/120
# 180/181 [============================>.] - ETA: 0s - loss: 0.0175 - accuracy: 0.9953
# Epoch 00094: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0174 - accuracy: 0.9954 - val_loss: 0.0906 - val_accuracy: 0.9752
# Epoch 95/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0153 - accuracy: 0.9965
# Epoch 00095: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0153 - accuracy: 0.9965 - val_loss: 0.0460 - val_accuracy: 0.9900
# Epoch 96/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9963
# Epoch 00096: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0150 - accuracy: 0.9963 - val_loss: 0.0411 - val_accuracy: 0.9910
# Epoch 97/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0145 - accuracy: 0.9969
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 2.6214399258606137e-05.
#
# Epoch 00097: val_accuracy did not improve from 0.99174
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0145 - accuracy: 0.9969 - val_loss: 0.0411 - val_accuracy: 0.9900
# Epoch 98/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0155 - accuracy: 0.9963
# Epoch 00098: val_accuracy improved from 0.99174 to 0.99243, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 47ms/step - loss: 0.0155 - accuracy: 0.9963 - val_loss: 0.0372 - val_accuracy: 0.9924
# Epoch 99/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9968
# Epoch 00099: val_accuracy did not improve from 0.99243
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0147 - accuracy: 0.9968 - val_loss: 0.0361 - val_accuracy: 0.9917
# Epoch 100/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9966
# Epoch 00100: val_accuracy did not improve from 0.99243
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0149 - accuracy: 0.9966 - val_loss: 0.0450 - val_accuracy: 0.9907
# Epoch 101/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9971
# Epoch 00101: val_accuracy did not improve from 0.99243
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0135 - accuracy: 0.9971 - val_loss: 0.0372 - val_accuracy: 0.9914
# Epoch 102/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9972
# Epoch 00102: val_accuracy did not improve from 0.99243
# 181/181 [==============================] - 8s 45ms/step - loss: 0.0135 - accuracy: 0.9972 - val_loss: 0.0390 - val_accuracy: 0.9921
# Epoch 103/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9968
# Epoch 00103: val_accuracy did not improve from 0.99243
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0137 - accuracy: 0.9968 - val_loss: 0.0374 - val_accuracy: 0.9917
# Epoch 104/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9969
# Epoch 00104: val_accuracy improved from 0.99243 to 0.99312, saving model to FontFromImage.model.h5
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.0351 - val_accuracy: 0.9931
# Epoch 105/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9968
# Epoch 00105: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0136 - accuracy: 0.9968 - val_loss: 0.0379 - val_accuracy: 0.9912
# Epoch 106/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9968
# Epoch 00106: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0142 - accuracy: 0.9968 - val_loss: 0.0429 - val_accuracy: 0.9910
# Epoch 107/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9965
# Epoch 00107: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0142 - accuracy: 0.9965 - val_loss: 0.0392 - val_accuracy: 0.9905
# Epoch 108/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9968
# Epoch 00108: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 45ms/step - loss: 0.0127 - accuracy: 0.9968 - val_loss: 0.0600 - val_accuracy: 0.9855
# Epoch 109/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9970
# Epoch 00109: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0131 - accuracy: 0.9970 - val_loss: 0.0370 - val_accuracy: 0.9919
# Epoch 110/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9976
# Epoch 00110: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0126 - accuracy: 0.9976 - val_loss: 0.0430 - val_accuracy: 0.9910
# Epoch 111/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0131 - accuracy: 0.9969
# Epoch 00111: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0131 - accuracy: 0.9969 - val_loss: 0.0410 - val_accuracy: 0.9914
# Epoch 112/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9979
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 2.09715188248083e-05.
#
# Epoch 00112: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0125 - accuracy: 0.9979 - val_loss: 0.0394 - val_accuracy: 0.9910
# Epoch 113/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.9967
# Epoch 00113: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0401 - val_accuracy: 0.9914
# Epoch 114/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9977
# Epoch 00114: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0116 - accuracy: 0.9977 - val_loss: 0.0376 - val_accuracy: 0.9916
# Epoch 115/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9972
# Epoch 00115: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0117 - accuracy: 0.9972 - val_loss: 0.0390 - val_accuracy: 0.9912
# Epoch 116/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9971
# Epoch 00116: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0124 - accuracy: 0.9971 - val_loss: 0.0406 - val_accuracy: 0.9907
# Epoch 117/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9971
# Epoch 00117: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0126 - accuracy: 0.9971 - val_loss: 0.0384 - val_accuracy: 0.9919
# Epoch 118/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9974
# Epoch 00118: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 46ms/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.0369 - val_accuracy: 0.9917
# Epoch 119/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9980
# Epoch 00119: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 45ms/step - loss: 0.0106 - accuracy: 0.9980 - val_loss: 0.0371 - val_accuracy: 0.9919
# Epoch 120/120
# 181/181 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9965
# Epoch 00120: ReduceLROnPlateau reducing learning rate to 1.6777214477770033e-05.
#
# Epoch 00120: val_accuracy did not improve from 0.99312
# 181/181 [==============================] - 8s 45ms/step - loss: 0.0129 - accuracy: 0.9965 - val_loss: 0.0383 - val_accuracy: 0.9919
# BestEpochResult. Epoch: 104, val_accuracy: 0.99312, accuracy: 0.99688, val_loss: 0.03511, loss: 0.01374,

# %% [markdown]
# ## Plot the loss and accuracy curves for training and validation.

# %%
# Condensed view 
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
def plot_loss(hist, name, plt):
    loss = hist['loss']
    val_loss = hist['val_loss']
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
def plot_accuracy(hist, name, plt):
    loss     = hist['accuracy']
    val_loss = hist['val_accuracy']
        
    plt.plot(loss,"--",linewidth=3,label="train:"+name)
    plt.plot(val_loss,linewidth=3,label="val:"+name)

# %%
plt.figure(figsize=(15, 10))
plot_loss(history.history, "model", plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log loss")
plt.show()

# %%
plt.figure(figsize=(15, 15))
plot_accuracy(history.history, "model", plt)
plt.legend()
plt.grid()
plt.yscale("log")
plt.xlabel("epoch")
plt.ylabel("log accuracy")
plt.show()

# %% [markdown]
# ## Delete the existing model + Load best model

# %%
# deletes the existing model
del model

# Load last saved model, ie the one with the best accuracy
model = load_model(h5_path)

# %% [markdown]
# ## Look at confusion matrix

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(15, 13))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(X_val)

# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 

# Convert validation observations to one hot vectors
Y_true = np.argmax(Y_val,axis = 1) 

# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 

# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(nb_fonts))

# %%
# We see that the "biggest" confusion exists between: 
# - 1: AlexBrush-Regular
# - 2: Allura-Regular

# %%
print("Y_pred shape: ", Y_pred.shape)                 # Prediction for each image in the validaset set
print("Y_pred_classes shape: ", Y_pred_classes.shape) # Index of the font prediction for each image in the val. set
print("Y_true shape: ", Y_true.shape)                 # Index of the actual font for each image in the val. set
print("confusion_mtx shape: ", confusion_mtx.shape)   # Values in the confusion matrix shown above
# Out:
# Y_pred shape:  (5810, 35)
# Y_pred_classes shape:  (5810,)
# Y_true shape:  (5810,)
# confusion_mtx shape:  (35, 35)

# %%
Y_pred_classes[0:12]
# Out:
# array([29, 11,  3, 28,  8, 14, 28, 28,  3, 29, 23, 31])

# %%
X_val.shape
# Out:
# (5810, 50, 50, 1)

# %% [markdown]
# ## Analyze the errors

# %%
# Display some error results 

# Errors are difference between predicted labels and true labels. Error[i] is True if this is an error
errors = (Y_pred_classes - Y_true != 0)

# Y_pred_errors: List of Images in the validation set where prediction was bad
X_val_errors = X_val[errors]

# Y_true_errors: Index of the actual font in the validation set where prediction was bad
Y_true_errors = Y_true[errors]

# Y_pred_classes_errors: The list of indexes for font predictions that were bad
Y_pred_classes_errors = Y_pred_classes[errors]

# Y_pred_errors: Prediction for each font in the validation set where prediction was bad
Y_pred_errors = Y_pred[errors]

# %%
def display_errors(errors_index, img_errors, pred_errors, obs_errors):
    """ This function shows images with their predicted and real labels"""

    fig = plt.figure(figsize=(13, 15))
#     fig.subplots_adjust(hspace=0.15, wspace=0.2, left=0, right=1, bottom=0, top=1)
    fig.subplots_adjust(hspace=0.13, wspace=0.2, left=0, right=1, bottom=0, top=1)
    # hspace=0.1, wspace=0.2, left=0, right=1, bottom=0, top=1
    nb_pictures = len(errors_index)
    
    for i in range(nb_pictures):
        ax = fig.add_subplot(nb_pictures//5 , 5, i+1, xticks=[], yticks=[]) 
        error = errors_index[i]
        plot_sample((img_errors[error]).reshape((image_size,image_size)), ax)
        ax.set_title("Pred: {}\nTrue : {}".format(output_labels[pred_errors[error]], output_labels[obs_errors[error]]))
    plt.show()

# %% [markdown]
# ### Show the biggest errors

# %%
# Probabilities of the wrong predicted numbers. Prob for the bad choice
Y_pred_errors_prob = np.max(Y_pred_errors, axis = 1)

# Predicted probabilities of the true values in the error set. Prob for the good choice
true_prob_errors = np.diagonal(np.take(Y_pred_errors, Y_true_errors, axis=1))

# Difference between the probability of the predicted label and the true label
delta_pred_true_errors = Y_pred_errors_prob - true_prob_errors

# Sorted list of the delta prob errors
sorted_delta_errors = np.argsort(delta_pred_true_errors)

# Top errors 
most_important_errors = sorted_delta_errors[-25:]

# Show the top errors
display_errors(most_important_errors, X_val_errors, Y_pred_classes_errors, Y_true_errors)

# %%
# We see that most errors are for individual characters for similar fonts. That's expected. Good.
#
# Note that some parts of images might be in the training dataset and also in the validation dataset. This
# would falsely improve the accuracy.

# %% [markdown]
# ## Show Saliency maps - Which pixels were used for predictions

# %%
def saliency_map(input_image, model, label, image_size, num_classes):
    '''
    Generates the saliency map of a given gray scale image.

    Args:
        image -- picture that the model will classify
        model (keras Model) -- classifier
        label (int) -- ground truth label of the image
        image_size (int)  -- Image size in pixels
        num_classes (int) -- number of classes for label
    '''

    input_image = input_image.reshape(image_size, image_size)
    
    # Add an additional dimension (for the batch)
    image = np.expand_dims(input_image, axis=0)

    # Define the expected output array by one-hot encoding the label
    # The length of the array is equal to the number of classes
    expected_output = tf.one_hot([label] * image.shape[0], num_classes)

    
    with tf.GradientTape() as tape:
        # cast image to float
        inputs = tf.cast(image, tf.float32)

        # watch the input pixels
        tape.watch(inputs)

        # generate the predictions
        predictions = model(inputs)

        # Calculate the loss
        loss = tf.keras.losses.categorical_crossentropy(expected_output, predictions)

    # get the gradients of the loss with respect to the model's input image
    gradients = tape.gradient(loss, inputs)
    
    # generate the grayscale tensor
    grayscale_tensor = tf.abs(gradients[0])

    # The max value in the grayscale tensor will be pushed to 1.0
    # The min value will be pushed to 0.
    normalized_tensor = (grayscale_tensor - tf.reduce_min(grayscale_tensor)) / \
         (tf.reduce_max(grayscale_tensor) - tf.reduce_min(grayscale_tensor))
    
    # Mix the saliency map with the original image
    mixed_image = input_image * 0.5 + normalized_tensor * 0.5

    return mixed_image.numpy()

# %%
# image_with_saliency = saliency_map( val_X[0], model, val_y[0], image_size, nb_fonts)

# plt.figure(figsize=(3, 3)) 
# plt.axis('off')
# plt.imshow(image_with_saliency, cmap='gray')
# plt.show()

# %%
def display_images_with_saliency_map(X, Y):
    """ This function shows Saliency maps for 25 images with their real labels"""

    fig = plt.figure(figsize=(13, 13))
    fig.subplots_adjust(hspace=0.1, wspace=0.2, left=0, right=1, bottom=0, top=1)
    nb_pictures = 25
    
    for i in range(nb_pictures):
        image_with_saliency = saliency_map(X[i], model, Y[i], image_size, nb_fonts)
        
        ax = fig.add_subplot(nb_pictures//5 , 5, i+1, xticks=[], yticks=[]) 
        plot_sample(image_with_saliency.reshape((image_size, image_size)), ax)
        ax.set_title("{}".format(output_labels[Y[i]]))
    plt.show()

# %%
# Do a visualization of which pixels the model is focusing on when making its predictions
display_images_with_saliency_map(X_val[:25], val_y[:25])

# %%
# Debugging information
print("Validation shape: ", errors.shape)                 
print("X_val_errors shape: ", X_val_errors.shape)  
print("Y_true_errors shape: ", Y_true_errors.shape)                 
print("Y_pred_classes_errors shape: ", Y_pred_classes_errors.shape)                 
print("Y_pred_errors shape: ", Y_pred_errors.shape)
# Out:
# Validation shape:  (5810,)
# X_val_errors shape:  (40, 50, 50, 1)
# Y_true_errors shape:  (40,)
# Y_pred_classes_errors shape:  (40,)
# Y_pred_errors shape:  (40, 35)

# %%
# More Debugging information
print("Y_pred_errors_prob shape: ", Y_pred_errors_prob.shape)                 
print("true_prob_errors shape: ", true_prob_errors.shape)  
print("delta_pred_true_errors shape: ", delta_pred_true_errors.shape)                 
print("sorted_delta_errors shape: ", sorted_delta_errors.shape)                 
print("most_important_errors shape: ", most_important_errors.shape)
# Out:
# Y_pred_errors_prob shape:  (40,)
# true_prob_errors shape:  (40,)
# delta_pred_true_errors shape:  (40,)
# sorted_delta_errors shape:  (40,)
# most_important_errors shape:  (25,)

# %%
#Y_pred_errors_prob[0:25]

# %% [markdown]
# ## Validation Accuracy

# %%
nb_errors = X_val_errors.shape[0]
nb_val_samples = Y_pred.shape[0]
accuracy = 1.0 - (nb_errors / nb_val_samples)

print("Validation Accuracy:", accuracy)
print(f"Number of errors: {nb_errors} from {nb_val_samples} predictions on validation set.")
# Out:
# Validation Accuracy: 0.9931153184165232
# Number of errors: 40 from 5810 predictions on validation set.

# %% [markdown]
# ## Conclusions

# %%
# Interesting. I am still amazed as I would not know how to program this in a non "machine learning" way.
# This is really a typical case where the model accuracy is very close to what
# only a trained font expert could do.
